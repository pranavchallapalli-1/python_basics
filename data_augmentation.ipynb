# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img

# %%
datagen=ImageDataGenerator(rotation_range=40,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.2,zoom_range=0.2,fill_mode='nearest',horizontal_flip=True)

# %%
img=load_img(r"./dog_img_for_augmentation.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=199x148>

# %%
x=img_to_array(img)
x=x.reshape((1,)+x.shape)
i=0
for batch in datagen.flow(x,batch_size=1,save_to_dir=r"./Augmented_trial/",save_prefix='dog',save_format='jpeg'):
    i+=1
    if i>30:
        break
